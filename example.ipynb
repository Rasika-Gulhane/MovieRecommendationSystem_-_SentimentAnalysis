# %%
a=25   #IF CELL RUNS PYTHON CONFIGURED

# %%
import pickle

# %%
import pandas as pd

# %%
df= pd.read_csv('main_data.csv')

# %%
df
# Out:
#           director_name           actor_1_name      actor_2_name
# 0         James Cameron            CCH Pounder  Joel David Moore  \
# 1        Gore Verbinski            Johnny Depp     Orlando Bloom
# 2            Sam Mendes        Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan              Tom Hardy    Christian Bale
# 4           Doug Walker            Doug Walker        Rob Walker
# ...                 ...                    ...               ...
# 6155   Robert Rodriguez  Priyanka Chopra Jonas      Pedro Pascal
# 6156    Paul Greengrass              Tom Hanks     Helena Zengel
# 6157        Regina King      Kingsley Ben-Adir         Eli Goree
# 6158    Emerald Fennell         Carey Mulligan        Bo Burnham
# 6159   Kornél Mundruczó          Vanessa Kirby      Shia LaBeouf
#
#               actor_3_name                           genres
# 0                Wes Studi  Action|Adventure|Fantasy|Sci-Fi  \
# 1           Jack Davenport         Action|Adventure|Fantasy
# ...

# %%
df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64
