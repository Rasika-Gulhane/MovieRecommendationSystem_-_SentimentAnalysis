# %%
import pandas as pd
import numpy as np

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
dfs = [df1, df2, df3, df4]
df = pd.concat(dfs, ignore_index=True)

# %%
df
# Out:
#              Opening  Opening.1                       Title
# 0      J A N U A R Y          5     Insidious: The Last Key  \
# 1      J A N U A R Y          5            The Strange Ones
# 2      J A N U A R Y          5                    Stratton
# 3      J A N U A R Y         10               Sweet Country
# 4      J A N U A R Y         12                The Commuter
# ..               ...        ...                         ...
# 270  D E C E M B E R         25             Holmes & Watson
# 271  D E C E M B E R         25                        Vice
# 272  D E C E M B E R         25         On the Basis of Sex
# 273  D E C E M B E R         25                   Destroyer
# 274  D E C E M B E R         28  Black Mirror: Bandersnatch
#
#                                     Production company
# 0    Universal Pictures / Blumhouse Productions / S...  \
# 1                               Vertical Entertainment
# 2                        Momentum Pictures / GFM Films
# ...

# %%
df_2018 = df[['Title','Cast and crew']]

# %%
df_2018
# Out:
#                           Title
# 0       Insidious: The Last Key  \
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 270             Holmes & Watson
# 271                        Vice
# 272         On the Basis of Sex
# 273                   Destroyer
# 274  Black Mirror: Bandersnatch
#
#                                          Cast and crew
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 270  Etan Cohen (director/screenplay); Will Ferrell...
# 271  Adam McKay (director/screenplay); Christian Ba...
# 272  Mimi Leder (director); Daniel Stiepleman (scre...
# ...

# %%
! pip install tmdbv3api

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '539e85067de975ed98423b9d9da95b1f'

# %%
from tmdbv3api import Movie
import ast
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if result:
        movie_id = result[0].id
        response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
        data_json = response.json()
        print(data_json)
        if data_json['genres']:
            genre_str = " " 
            for i in range(0,len(data_json['genres'])):
                genres.append(data_json['genres'][i]['name'])
            return genres
        else:
            np.nan
    else:
      np.nan

# %%
df_2018['Genre'] = df_2018['Title'].map(lambda x: get_genre(str(x)))
# Out:
# {'adult': False, 'backdrop_path': '/PwI3EfasE9fVuXsmMu9ffJh0Re.jpg', 'belongs_to_collection': {'id': 228446, 'name': 'Insidious Collection', 'poster_path': '/w1213HKk1XKSwHiBgjkWghn9biC.jpg', 'backdrop_path': '/5FrPZHgbbmTIq0oxpwSGqu5HyXC.jpg'}, 'budget': 10000000, 'genres': [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'name': 'Mystery'}, {'id': 53, 'name': 'Thriller'}], 'homepage': 'http://www.insidiousmovie.com', 'id': 406563, 'imdb_id': 'tt5726086', 'original_language': 'en', 'original_title': 'Insidious: The Last Key', 'overview': 'Parapsychologist Elise Rainier and her team travel to Five Keys, NM, to investigate a man’s claim of a haunting. Terror soon strikes when Rainier realizes that the house he lives in was her family’s old home.', 'popularity': 45.177, 'poster_path': '/nb9fc9INMg8kQ8L7sE7XTNsZnUX.jpg', 'production_companies': [{'id': 11341, 'logo_path': '/xytTBODEy3p20ksHL4Ftxr483Iv.png', 'name': 'Stage 6 Films', 'origin_country': 'US'}, {'id': 3172, 'logo_path': '/kDedjRZ
# ...

# %%
df_2018
# Out:
#                           Title
# 0       Insidious: The Last Key  \
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 270             Holmes & Watson
# 271                        Vice
# 272         On the Basis of Sex
# 273                   Destroyer
# 274  Black Mirror: Bandersnatch
#
#                                          Cast and crew
# 0    Adam Robitel (director); Leigh Whannell (scree...  \
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 270  Etan Cohen (director/screenplay); Will Ferrell...
# 271  Adam McKay (director/screenplay); Christian Ba...
# 272  Mimi Leder (director); Daniel Stiepleman (scre...
# ...

# %%
# df_2018['genres'] = df_2018['Genre'].map(lambda x: list_to_string(x))
df_2018['Genre'] = df_2018['Genre'].apply(lambda x: ', '.join(x))
df_2018['genres'] = df_2018['Genre'].str.replace(',', ' ')
# Out:
# /var/folders/qv/gqb3583x48g_90k1j3lvlvyr0000gn/T/ipykernel_49722/3659375731.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['Genre'] = df_2018['Genre'].apply(lambda x: ', '.join(x))
# /var/folders/qv/gqb3583x48g_90k1j3lvlvyr0000gn/T/ipykernel_49722/3659375731.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['genres'] = df_2018['Genre'].str.replace(',', ' ')

# %%
df_2018
# Out:
#                           Title
# 0       Insidious: The Last Key  \
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 270             Holmes & Watson
# 271                        Vice
# 272         On the Basis of Sex
# 273                   Destroyer
# 274  Black Mirror: Bandersnatch
#
#                                          Cast and crew
# 0    Adam Robitel (director); Leigh Whannell (scree...  \
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 270  Etan Cohen (director/screenplay); Will Ferrell...
# 271  Adam McKay (director/screenplay); Christian Ba...
# 272  Mimi Leder (director); Daniel Stiepleman (scre...
# ...

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))
# Out:
# /var/folders/qv/gqb3583x48g_90k1j3lvlvyr0000gn/T/ipykernel_49722/930721595.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# /var/folders/qv/gqb3583x48g_90k1j3lvlvyr0000gn/T/ipykernel_49722/2274966287.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2018
# Out:
#                           Title
# 0       Insidious: The Last Key  \
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 270             Holmes & Watson
# 271                        Vice
# 272         On the Basis of Sex
# 273                   Destroyer
# 274  Black Mirror: Bandersnatch
#
#                                          Cast and crew
# 0    Adam Robitel (director); Leigh Whannell (scree...  \
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 270  Etan Cohen (director/screenplay); Will Ferrell...
# 271  Adam McKay (director/screenplay); Christian Ba...
# 272  Mimi Leder (director); Daniel Stiepleman (scre...
# ...

# %%
df_2018 = df_2018.rename(columns={'Title':'movie_title'})

# %%
new_df18 = df_2018.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df18
# Out:
#           director_name     actor_1_name            actor_2_name
# 0          Adam Robitel        Lin Shaye           Angus Sampson  \
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 270          Etan Cohen     Will Ferrell          John C. Reilly
# 271          Adam McKay   Christian Bale               Amy Adams
# 272          Mimi Leder   Felicity Jones            Armie Hammer
# 273        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 274         David Slade  Fionn Whitehead            Will Poulter
#
#        actor_3_name                                             genres
# 0    Leigh Whannell                          Horror  Mystery  Thriller  \
# ...

# %%
new_df18.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name     10
# actor_3_name     27
# genres            0
# movie_title       0
# dtype: int64

# %%
new_df18['actor_2_name'] = new_df18['actor_2_name'].replace(np.nan, 'unknown')
new_df18['actor_3_name'] = new_df18['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df18['movie_title'] = new_df18['movie_title'].str.lower()

# %%
new_df18['comb'] = new_df18['actor_1_name'] + ' ' + new_df18['actor_2_name'] + ' '+ new_df18['actor_3_name'] + ' '+ new_df18['director_name'] +' ' + new_df18['genres']

# %%
new_df18
# Out:
#           director_name     actor_1_name            actor_2_name
# 0          Adam Robitel        Lin Shaye           Angus Sampson  \
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 270          Etan Cohen     Will Ferrell          John C. Reilly
# 271          Adam McKay   Christian Bale               Amy Adams
# 272          Mimi Leder   Felicity Jones            Armie Hammer
# 273        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 274         David Slade  Fionn Whitehead            Will Poulter
#
#        actor_3_name                                             genres
# 0    Leigh Whannell                          Horror  Mystery  Thriller  \
# ...

# %% [markdown]
# ## Extracting Feature of 2019 movies from wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
dfs = [df1, df2, df3, df4]
df = pd.concat(dfs, ignore_index=True)

# %%
df
# Out:
#              Opening  Opening.1              Title
# 0      J A N U A R Y          4        Escape Room  \
# 1      J A N U A R Y          4         Rust Creek
# 2      J A N U A R Y          4   American Hangman
# 3      J A N U A R Y         11   A Dog's Way Home
# 4      J A N U A R Y         11         The Upside
# ..               ...        ...                ...
# 240  D E C E M B E R         25  Spies in Disguise
# 241  D E C E M B E R         25       Little Women
# 242  D E C E M B E R         25               1917
# 243  D E C E M B E R         25         Just Mercy
# 244  D E C E M B E R         27           Clemency
#
#                                     Production company
# 0                    Columbia Pictures / Original Film  \
# 1                       IFC Films / Lunacy Productions
# 2                          Hangman Justice Productions
# 3                                    Columbia Pictures
# 4                                    STX Entertainment
# ...

# %%
df_2019 = df[['Title','Cast and crew']]

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '539e85067de975ed98423b9d9da95b1f'

# %%
from tmdbv3api import Movie
import ast
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if result:
        movie_id = result[0].id
        response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
        data_json = response.json()
        print(data_json)
        if data_json['genres']:
            genre_str = " " 
            for i in range(0,len(data_json['genres'])):
                genres.append(data_json['genres'][i]['name'])
            return genres
        else:
            np.nan
    else:
      np.nan

# %%
df_2019['Genre'] = df_2019['Title'].map(lambda x: get_genre(str(x)))
# Out:
# {'adult': False, 'backdrop_path': '/mWLljCmpqlcYQh7uh51BBMwCZwN.jpg', 'belongs_to_collection': {'id': 769423, 'name': 'Escape Room Collection', 'poster_path': '/6xjebYUN0vxRvZRcItlSf0rRIJ0.jpg', 'backdrop_path': '/jMdEW5QcRZ7WShJo3ZsMgNGdJIJ.jpg'}, 'budget': 9000000, 'genres': [{'id': 27, 'name': 'Horror'}, {'id': 53, 'name': 'Thriller'}, {'id': 9648, 'name': 'Mystery'}], 'homepage': 'https://www.escaperoom.movie/', 'id': 522681, 'imdb_id': 'tt5886046', 'original_language': 'en', 'original_title': 'Escape Room', 'overview': 'Six strangers find themselves in circumstances beyond their control, and must use their wits to survive.', 'popularity': 33.851, 'poster_path': '/8Ls1tZ6qjGzfGHjBB7ihOnf7f0b.jpg', 'production_companies': [{'id': 333, 'logo_path': '/5xUJfzPZ8jWJUDzYtIeuPO4qPIa.png', 'name': 'Original Film', 'origin_country': 'US'}, {'id': 5, 'logo_path': '/71BqEFAF4V3qjjMPCpLuyJFB9A.png', 'name': 'Columbia Pictures', 'origin_country': 'US'}, {'id': 34, 'logo_path': '/GagSvqWlyPdkF
# ...

# %%
df_2019
# Out:
#                  Title                                      Cast and crew
# 0          Escape Room  Adam Robitel (director); Bragi F. Schut, Maria...  \
# 1           Rust Creek  Jen McGowan (director); Julie Lipson (screenpl...
# 2     American Hangman  Wilson Coneybeare (director/screenplay); Donal...
# 3     A Dog's Way Home  Charles Martin Smith (director); W. Bruce Came...
# 4           The Upside  Neil Burger (director); Jon Hartmere (screenpl...
# ..                 ...                                                ...
# 240  Spies in Disguise  Nick Bruno, Troy Quane (directors); Brad Copel...
# 241       Little Women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 242               1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 243         Just Mercy  Destin Daniel Cretton (director/screenplay), A...
# 244           Clemency  Chinonye Chukwu (director/screenplay); Alfre W...
#
#                                               Genre
# ...

# %%
# df_2018['genres'] = df_2018['Genre'].map(lambda x: list_to_string(x))
df_2019['Genre'] = df_2019['Genre'].apply(lambda x: ', '.join(x))
df_2019['genres'] = df_2019['Genre'].str.replace(',', ' ')
# Out:
# /var/folders/qv/gqb3583x48g_90k1j3lvlvyr0000gn/T/ipykernel_49722/1461344147.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['Genre'] = df_2019['Genre'].apply(lambda x: ', '.join(x))
# /var/folders/qv/gqb3583x48g_90k1j3lvlvyr0000gn/T/ipykernel_49722/1461344147.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['genres'] = df_2019['Genre'].str.replace(',', ' ')

# %%
df_2019
# Out:
#                  Title                                      Cast and crew
# 0          Escape Room  Adam Robitel (director); Bragi F. Schut, Maria...  \
# 1           Rust Creek  Jen McGowan (director); Julie Lipson (screenpl...
# 2     American Hangman  Wilson Coneybeare (director/screenplay); Donal...
# 3     A Dog's Way Home  Charles Martin Smith (director); W. Bruce Came...
# 4           The Upside  Neil Burger (director); Jon Hartmere (screenpl...
# ..                 ...                                                ...
# 240  Spies in Disguise  Nick Bruno, Troy Quane (directors); Brad Copel...
# 241       Little Women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 242               1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 243         Just Mercy  Destin Daniel Cretton (director/screenplay), A...
# 244           Clemency  Chinonye Chukwu (director/screenplay); Alfre W...
#
#                                             Genre
# ...

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(x))
# Out:
# /var/folders/qv/gqb3583x48g_90k1j3lvlvyr0000gn/T/ipykernel_49722/2296556331.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(x))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2019 = df_2019.rename(columns={'Title':'movie_title'})

# %%
new_df19 = df_2019.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df19.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      0
# actor_3_name     17
# genres            0
# movie_title       0
# dtype: int64

# %%
new_df19['actor_2_name'] = new_df19['actor_2_name'].replace(np.nan, 'unknown')
new_df19['actor_3_name'] = new_df19['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df19['movie_title'] = new_df19['movie_title'].str.lower()

# %%
new_df19.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# dtype: int64

# %%
new_df19['comb'] = new_df19['actor_1_name'] + ' ' + new_df19['actor_2_name'] + ' '+ new_df19['actor_3_name'] + ' '+ new_df19['director_name'] +' ' + new_df19['genres']

# %%
my_df = pd.concat((new_df18,new_df19), ignore_index=True)

# %%
my_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
old_df = pd.read_csv('new_data.csv')

# %%
old_df
# Out:
#               director_name          actor_1_name            actor_2_name
# 0             James Cameron           CCH Pounder        Joel David Moore  \
# 1            Gore Verbinski           Johnny Depp           Orlando Bloom
# 2                Sam Mendes       Christoph Waltz            Rory Kinnear
# 3         Christopher Nolan             Tom Hardy          Christian Bale
# 4               Doug Walker           Doug Walker              Rob Walker
# ...                     ...                   ...                     ...
# 5359            Jim Strouse      Jessica Williams            Chris O'Dowd
# 5360            Farhad Mann         Adelaide Kane  Benjamin Hollingsworth
# 5361       Hannaleena Hauru        Inka Haapamäki           Rosa Honkonen
# 5362  Jonathan A. Rosenbaum  Lou Diamond Phillips           Wallace Shawn
# 5363           Ravi Udyawar        Sridevi Kapoor               Sajal Ali
#
#               actor_3_name                           genres
# ...

# %%
final_df = pd.concat((old_df,my_df), ignore_index=True)
final_df
# Out:
#                director_name       actor_1_name       actor_2_name
# 0              James Cameron        CCH Pounder   Joel David Moore  \
# 1             Gore Verbinski        Johnny Depp      Orlando Bloom
# 2                 Sam Mendes    Christoph Waltz       Rory Kinnear
# 3          Christopher Nolan          Tom Hardy     Christian Bale
# 4                Doug Walker        Doug Walker         Rob Walker
# ...                      ...                ...                ...
# 5879  Nick Bruno, Troy Quane         Will Smith         Will Smith
# 5880            Greta Gerwig      Saoirse Ronan      Saoirse Ronan
# 5881              Sam Mendes      George MacKay      George MacKay
# 5882   Destin Daniel Cretton  Michael B. Jordan  Michael B. Jordan
# 5883         Chinonye Chukwu      Alfre Woodard      Alfre Woodard
#
#               actor_3_name                                        genres
# 0                Wes Studi               Action|Adventure|Fantasy|Sci-Fi  \
# ...

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
final_df.to_csv('final_data.csv',index=False)
